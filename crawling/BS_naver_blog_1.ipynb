# %% [markdown]
# # 네이버 블로그 검색결과 크롤링 (1)

# %%
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query='

# %%
keyword = input()

# %%
search_url = base_url + keyword
search_url
# Out:
# 'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query=돈가스'

# %%
r = requests.get(search_url)
r.text
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="돈가스 : 네이버 블로그검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'돈가스\'의 네이버 블로그검색 결과입니다."> <meta name="description" lang="ko" content="\'돈가스\'의 네이버 블로그검색 결과입니다."> <title>돈가스 : 네이버 블로그검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_250109.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_250116.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\\/\\*/, \'\').replace(/\\*\\//, \'\')); } function trim_crlf (q) { var crlf = /[\\r|\\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = \'utf-8\' ; document.getElementsByTagName(\'head\')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement(\'link\') ; l.type = \'text/css\' ; l.rel = \'stylesheet\' ; if (charset) l.charset = charset ; else l.charset = \'utf-8\' ; l.media = \'screen\' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=\'\'; mid.style.visibility=\'visible\'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden(\'"+id+"\')",100); } function hidden (id) { var mid=document.getElementById( ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="돈가스 : 네이버 블로그검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'돈가스'의 네이버 블로그검색 결과입니다." property="og:description"/> <meta content="'돈가스'의 네이버 블로그검색 결과입니다." lang="ko" name="description"/> <title>돈가스 : 네이버 블로그검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_250109.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_250116.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibili ...
# <form action="" id="view_form" method="get" name="view_form"> <input id="view_ssc" name="ssc" type="hidden" value="tab.blog.all"/> <input id="view_query" name="query" type="hidden" value="돈가스"/> <input id="view_sm" name="sm" type="hidden" value="tab_opt"/> <input id="view_nso" name="nso" type="hidden" value=""/> </form> <script> function view_init_form() { document.forms["view_form"]["query"].value = decodeURIComponent("%EB%8F%88%EA%B0%80%EC%8A%A4"); document.forms["view_form"]["nso"].value = decodeURIComponent(""); } function view_submit_sort_option(value) { view_init_form(); var area = ""; if (value == 1) { area = "new"; document.getElementById("view_form")["nso"].value = "so:dd,p:all"; } else { area = "sim"; document.getElementById("view_form")["nso"].value = "so:r,p:all"; } var cr = "opt." + area; formCR("view_form", cr); } function view_submit_date_option(value, e) { view_init_form(); var so = "r"; var cr = ""; if (value == 8) { var start = e.startDate; var end = e.endDate; var startdate = start.year + start.month + start.date; var enddate = end.year + end.month + end.date; var nso_startdate = startdate.replace(/\./gi, ""); var nso_enddate = enddate.replace(/\./gi, ""); cr = "opt.set"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:from" + nso_startdate + "to" + nso_enddate; } else if (value == 1) { cr = "opt.1hr"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1h"; } else if (value == 2) { cr = "opt.1day"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1d"; } else if (value == 3) { cr = "opt.1week"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1w"; } else if (value == 4) { cr = "opt.1mon"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1m"; } else if (value == 5) { cr = "opt.3mon"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:3m"; } else if (value == 6) { cr = "opt.6mon"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:6m"; } else if (value == 7) { cr = "opt.1yr"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1y"; } else { cr = "opt.all"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:all"; } formCR("view_form", cr); } </script> <div id="snb"> <div class="mod_group_option_filter _search_option_simple_wrap" style=""> <div class="mod_list_option_filter"> <div aria-label="정렬 필터를 선택하세요" class="option_area type_sort" role="listbox"> <a aria-selected="true" class="item" href="#" onclick="view_submit_sort_option(0); return false;" role="option">관련도순</a> <a aria-selected="false" class="item" href="#" onclick="view_submit_sort_option(1); return false;" role="option">최신순</a> </div> <div class="option_filter"> <a aria-expanded="false" aria-haspopup="listbox" aria-label="검색옵션 열기" class="btn_option _search_option_open_btn" href="javascript:;" onclick="tCR('a=opt.unfd');" role="button">옵션<i class="spnew ico_filter_arr"></i></a> </div> </div> </div> <div class="mod_group_option_sort _search_option_detail_wrap" role="listbox" style="display:none;"> <div class="mod_list_option_filter"> <div class="option_filter"> <a aria-expanded="true" aria-haspopup="listbox" aria-label="검색옵션 닫기" class="btn_option _search_option_close_btn" href="javascript:;" onclick="tCR('a=opt.fold');" role="button">옵션<i class="spnew ico_filter_arr"></i></a> </div> </div> <ul class="lst_option"> <li class="bx lineup"> <div class="bx_inner"> <strong class="tit">정렬</strong> <div class="option" role="tablist"> <a aria-selected="true" class="txt" href="#" onclick="view_submit_sort_option(0); return false;" role="tab">관련도순</a> <a aria-selected="false" class="txt" href="#" onclick="view_submit_sort_option(1); return false;" role="tab">최신순</a> </div> </div> </li> <li class="bx term"> <div class="bx_inner"> <strong class="tit">기간</strong> <div class="option" role="tablist"> <a aria-selected="true" class="txt" href="#" onclick="view_submit_date_option(0); return false;" role="ta ...
#   if (typeof NAVER === "undefined") {
#     NAVER = {};
#   }
#   if (typeof NAVER.SEARCH_AD === "undefined") {
#     NAVER.SEARCH_AD = {};
#   }
#   NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#           clearTimeout(timerAttribute);
#           parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#   };
#   NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#           var timer = setTimeout(function () {
#               var tooltipElement = $Element(parentElement.query("._tooltip"));
#               tooltipElement.css("display", "none");
#           }, 100);
#           parentElement.attr("data-timer", timer);
#       }
#   };
#
#   var _elAdIndLayerTab = null;
#   var _elAdIndLayerTimeTab;
#   var _elDscNcautionTab = null;
#
#   function adInfoShowTab(el) {
#     if (_elAdIndLayerTab && _elAdIndLayerTab.visible()) {
#       return false;
#     } else {
#       if (!_elDscNcautionTab) {
#         _elDscNcautionTab = $Element(el).parent();
#       }
#       _elAdIndLayerTab = _elDscNcautionTab.next().next();
#       _elAdIndLayerTab.show();
#       _elAdIndLayerTimeTab = (new Date()).getTime();
#       return true;
#     }
#   }
#
#   function adInfoHideTab() {
#     if (_elAdIndLayerTab) {
#       _elAdIndLayerTab.hide();
#     }
#   }
#
#   function adInfoHideClickEventHandlerTab(e) {
#     if (_elAdIndLayerTimeTab + 200 < (new Date()).getTime()) adInfoHideTab();
#   }
#
#   document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerTab, false);
# </script>
# <script>
#   (function () {
#     var defaultFavicon = "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png";
#     naver.common.imageLazyLoader.onError(
#             naver.common.LazySrc.Handler.create({
#               "power-link-favicon-error": function ($img) {
#                 $img.attr("src", defaultFavicon);
#               }
#             })
#     );
#   })();
# </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/241121/css/nx_tab_powerlink.css" rel="stylesheet" type="text/css"/>
# <div class="sc_new ad_section section">
# <div class="api_subject_bx">
# <div class="mod_title_area">
# <div class="title_wrap">
# <h2 class="title">파워링크</h2>
# <span class="sub">
# <span class="title_text">
# <em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">돈가스</strong>
# <em class="dsc_ncaution_quotation">’</em>관련광고
#             </span>
# </span>
# <a class="api_ad_link" href="javascript:void(0);" onclick="if(adInfoShowTab(this)) goOtherCR(this, 'a=tsa.adset&amp;r=0&amp;i=tsaadset&amp;u='+urlencode(this.href));" role="button">
# <i class="spnew api_ico_alert">이 광고가 표시된 이유</i>
# </a>
# </div>
# <div class="title_sub">
# <a class="sub_link" href="//saedu.naver.com/adbiz/searchad/clickChoice.naver" onclick="return goOtherCR(this, 'a=tsa.registration&amp;r=0&amp;i=tsaregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ly_api_info" style="display: none;">
# <p class="dsc">이 광고는 사이트검색광고(파워링크)로, 검색어와 광고의 연관도, 광고주의 입찰가 등에 의해 광고 노출 여부와 순위가 결정됩니다.</p>
# <div class="btn_area">
# <a class="link" href="https://help.naver.com/service/5626/contents/1419">도움말</a>
# </div>
# <button class="btn_close" onclick="adInfoHideTab();" type="button">
# <i class="spnew ico_close">정보확인 레이어 닫기</i>
# </button>
# </div>
# </div>
# <div class="nad_area">
# <ul class="lst_type">
# <li class="lst many_txt ext_price type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=Bnj1xu9usdU+dtc+SNpVk////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d='+urlencode('http://ukuya-family.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=http%3A%2F%2Fukuya-family.co.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=Bnj1xu9usdU+dtc+SNpVk////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d='+urlencode('http://ukuya-family.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">우쿠야</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Bnj1xu9usdU+dtc+SNpVk////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d='+urlencode('http://ukuya-family.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">ukuya-family.co.kr</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=Bnj1xu9usdU+dtc+SNpVk////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d=' + urlencode('http://ukuya-family.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">서울A급상권 창업모집 우쿠야</span><span class="lnk_tit_txt">우동 돈까스 덮밥 브랜드</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=Bnj1xu9usdU+dtc+SNpVk////w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d=' + urlencode('http://ukuya-family.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#                       가맹비 1천만원 면제, 로열티 면제, 오픈 프로모션 지원, 소규모 10평도 가능! 극강의 가성비 창업 아이템
#
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=Bnj1xu9usdU+dtc+SNpVk////w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d=' + urlencode('http://ukuya-family.co.kr') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAyNDExMTRfMjIz/MDAxNzMxNTczNzA4OTU1.kyFzE5JSMnmG-cIaJc8fqLCzorEgf2pjWn-oWXdgvnkg.YPzzrsSEf7u45hJ1E6zJ7rcM-2xsZOeN-oTtW3MuePQg.JPEG/1767117-d48e258d-1a15-4a7e-a6e2-02525ce9903c.jpg" width="68"/>
# </a>
# </div>
# <ul class="lst_price">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=M28P7EXNdxn+uNaHDos6q////w==..." onclick="return goOtherCR(this,'a=tsa.pricelink1&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d='+urlencode('http://ukuya-family.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">800,000원</span>
# <div class="txt_area">
# <div class="txt">10평대 매장 일매출</div>
# <span class="dashed"></span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=67e/iw6twtn46apEPFluQP///w==..." onclick="return goOtherCR(this,'a=tsa.pricelink2&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d='+urlencode('http://ukuya-family.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">3,900원</span>
# <div class="txt_area">
# <div class="txt">우쿠야 우동</div>
# <span class="dashed"></span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=zBl6fG40p6mCXxILhmA60f///w==..." onclick="return goOtherCR(this,'a=tsa.pricelink3&amp;r=1&amp;i=nad-a001-01-000000347429764&amp;d='+urlencode('http://ukuya-family.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">4,900원</span>
# <div class="txt_area">
# <div class="txt">우쿠야 덮밥</div>
# <span class="dashed"></span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="lst many_txt type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=sci+WfYx4yVt0tju7X8c9v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=2&amp;i=nad-a001-01-000000220383412&amp;d='+urlencode('http://kumhwaking.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fkumhwaking.co.kr%2Fimg%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=sci+WfYx4yVt0tju7X8c9v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000220383412&amp;d='+urlencode('http://kumhwaking.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">금화왕돈까스창업</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=sci+WfYx4yVt0tju7X8c9v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=2&amp;i=nad-a001-01-000000220383412&amp;d='+urlencode('http://kumhwaking.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">kumhwaking.co.kr</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=sci+WfYx4yVt0tju7X8c9v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=2&amp;i=nad-a001-01-000000220383412&amp;d=' + urlencode('http://kumhwaking.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">가성비소자본창업 금화왕돈까스</span><span class="lnk_tit_txt">배달/포장/홀 3중 매출</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=sci+WfYx4yVt0tju7X8c9v///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=2&amp;i=nad-a001-01-000000220383412&amp;d=' + urlencode('http://kumhwaking.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       D급상권 입소문만으로 월매출1억3천! 홀, 배달, 매장 3중매출! 가성비창업
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=sci+WfYx4yVt0tju7X8c9v///w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=2&amp;i=nad-a001-01-000000220383412&amp;d=' + urlencode('http://kumhwaking.co.kr') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAyMjEyMjFfNDYg/MDAxNjcxNTg3NzM2NDAz.GS9-2n2G8KkJsR4JjgdCwkzKbdkzxOkxnoK6FVb0bQ4g.zgRSQAtq7lN4m0Hgo0tNrspSwTMUjjv9hWJWBFCChEYg.JPEG/2735763-7a92a86d-b98c-4f4c-bfe6-1141587c48e2.jpg" width="68"/>
# </a>
# </div>
# </li>
# <li class="lst many_txt ext_link type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=rhRG1Rt+uQfTVBuhu27W1v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d='+urlencode('http://www.jscook.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=http%3A%2F%2Fwww.jscook.co.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=rhRG1Rt+uQfTVBuhu27W1v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d='+urlencode('http://www.jscook.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">jscook.co.kr</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=rhRG1Rt+uQfTVBuhu27W1v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d=' + urlencode('http://www.jscook.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt"><strong class="hl">돈가스</strong> 전수전문 정성쿡</span><span class="lnk_tit_txt">외식창업 매출역전 상담</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=rhRG1Rt+uQfTVBuhu27W1v///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d=' + urlencode('http://www.jscook.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       37년 명장들의 <strong class="hl">돈가스</strong>비법전수, 창업노하우완벽전수 개인창업교육기관, 무료컨설팅지원
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=rhRG1Rt+uQfTVBuhu27W1v///w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d=' + urlencode('http://www.jscook.co.kr') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAxOTA4MTlfMjYw/MDAxNTY2MjAwMDMyNDkz.IAgfoTVJ_b-xIOWajM0Wna12X1UvCzg3d4CzWfMr4vwg.lgdsIKLfn6pkMX1DWW4HTnvGY39w4uso_-L3-DX_cH4g.JPEG/303229-4867becf-bdea-4975-9436-35042d37aa60.jpg" width="68"/>
# </a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=g8gHsdGlNBVO2Cs/xsZMZP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink1&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d='+urlencode('http://www.jscook.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">학원소개</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=5XCOAu78ULzUut0bwqcReP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink2&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d='+urlencode('http://www.jscook.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">교육과정</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=wjU5s/NajNpvf//oT6zQI////w==..." onclick="return goOtherCR(this,'a=tsa.sublink3&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d='+urlencode('http://www.jscook.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">수강생스토리</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=L2Bgod55ZB0KGXshB/jqQv///w==..." onclick="return goOtherCR(this,'a=tsa.sublink4&amp;r=3&amp;i=nad-a001-01-000000140521842&amp;d='+urlencode('http://www.jscook.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">세미나신청</a>
# </li>
# </ul>
# </li>
# <li class="lst many_txt ext_price type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=ialBlDGDGrNGncvFjkYP4P///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d='+urlencode('http://katsukb.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=http%3A%2F%2Fkatsukb.com%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ialBlDGDGrNGncvFjkYP4P///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d='+urlencode('http://katsukb.com')+'&amp;u='+urlencode(this.href));" target="_blank">katsukb.com</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=ialBlDGDGrNGncvFjkYP4P///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d=' + urlencode('http://katsukb.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">요즘대세 핫플 카츠공방창업</span><span class="lnk_tit_txt">직영점과 원가율 동일</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=ialBlDGDGrNGncvFjkYP4P///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d=' + urlencode('http://katsukb.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       극소점포도OK, 매출로 말하는 돈까스맛집, SNS인기, 요리초보도 전문쉐프로!
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=ialBlDGDGrNGncvFjkYP4P///w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d=' + urlencode('http://katsukb.com') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAyMjA4MThfMjYz/MDAxNjYwODIwMjQ2Nzc4.bXKI9xFRfv8mcmZMdxHDyH7s4sw6ShXt-ryZmFaaKOYg.btBk07G5cV8btEiXbTD960FBBa5ZAJr9Pm-xEfv5Z9Ag.PNG/2450750-fcc2893e-56a1-48cd-9a6b-ee446783c08d.png" width="68"/>
# </a>
# </div>
# <ul class="lst_price">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=wiE7m8sCzLtgFvf/TlrQof///w==..." onclick="return goOtherCR(this,'a=tsa.pricelink1&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d='+urlencode('http://katsukb.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">99,999,999원</span>
# <div class="txt_area">
# <div class="txt">서초본점 월매출</div>
# <span class="dashed"></span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=bbF55YglrY2bidAFJAyTfP///w==..." onclick="return goOtherCR(this,'a=tsa.pricelink2&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d='+urlencode('http://katsukb.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">88,000,000원</span>
# <div class="txt_area">
# <div class="txt">내방역점 월매출</div>
# <span class="dashed"></span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=0J+fmbyA1LKu0zJtIs9iPP///w==..." onclick="return goOtherCR(this,'a=tsa.pricelink3&amp;r=4&amp;i=nad-a001-01-000000203616471&amp;d='+urlencode('http://katsukb.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">70,000,000원</span>
# <div class="txt_area">
# <div class="txt">교대점 월매출</div>
# <span class="dashed"></span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="lst many_txt ext_link type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=nPQLyXi4xcD1bSHxv59/tv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.jumpoline.com%2F_images%2Fcommon%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=nPQLyXi4xcD1bSHxv59/tv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">점포라인</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=nPQLyXi4xcD1bSHxv59/tv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">jumpoline.com</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=nPQLyXi4xcD1bSHxv59/tv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d=' + urlencode('http://www.jumpoline.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">돈까스우동점 매매 점포라인</span><span class="lnk_tit_txt">빠른 직거래 &amp; 안전중개거래</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=nPQLyXi4xcD1bSHxv59/tv///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d=' + urlencode('http://www.jumpoline.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       31년전통, 100% 실매물, 매출보증, 주인 직접통화, 직거래, 150명에이전트
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=nPQLyXi4xcD1bSHxv59/tv///w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d=' + urlencode('http://www.jumpoline.com') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAyMDEwMDhfMjA3/MDAxNjAyMTE3NzM1MjQx.q_EZW24jWG1jNzUJ1rFuA9O0TYA_ggGWZZ8ely6OSr0g.hc_fJAGPoCxoAYtuEs2NKkdB0g4KwWfKxHogrg4OagUg.PNG/324779-9ae0e148-f7bb-471a-ac4d-1bc1168b8f83.png" width="68"/>
# </a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=+TP0k+UdSI3Jz1Sr0c326////w==..." onclick="return goOtherCR(this,'a=tsa.sublink1&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">매물정보</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=GDSzHihFMx3g7aF4i3Gp6f///w==..." onclick="return goOtherCR(this,'a=tsa.sublink2&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">계약후기</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=klPaYQ2Qgf+nCul2bafNNP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink3&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">매매상담</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=f949ACNuKkQyGt62tNUULv///w==..." onclick="return goOtherCR(this,'a=tsa.sublink4&amp;r=5&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">에이전트</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     (function() {
#         var createPlaceImageConveyer = function() {
#             var prev = document.getElementById("_place_prev_button");
#             var next = document.getElementById("_place_next_button");
#             if (prev == null || next == null) {
#                 return;
#             }
#             prev.style.display = "none";
#             var require = window.require.config({
#                 context: "impression_neo_place_extension",
#                 paths: {
#                     "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#                 }
#             });
#             require(["egjsConveyer"], function(egjsConveyer) {
#                 var conveyer = new egjsConveyer("#place_flicking", { autoInit: false, preventClickOnDrag: true});
#
#
#                 conveyer.subscribe("isReachStart", function(isReachStart) {
#                     prev.style.display = isReachStart ? "none" : "block";
#                 });
#
#                 conveyer.subscribe("isReachEnd", function(isReachEnd) {
#                     next.style.display = isReachEnd ? "none" : "block";
#                 });
#                 conveyer.init();
#
#                 if (!conveyer.isReachEnd) {
#                     next.style.display = "block";
#                 }
#
#                 prev.addEventListener("click", function() {
#                     conveyer.scrollIntoView("start", {
#                         align: "end",
#                         duration: 500,
#                         excludeStand: true,
#                     });
#                 });
#                 next.addEventListener("click", function() {
#                     conveyer.scrollIntoView("end", {
#                         align: "start",
#                         duration: 500,
#                         excludeStand: true,
#                     });
#                 });
#             });
#         };
#         nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#     })();
# </script>
# <script type="text/javascript">
#   (function () {
#     var createShoppingImageConveyer = function () {
#       var prev = document.getElementById("_shopping_prev_button");
#       var next = document.getElementById("_shopping_next_button");
#       if (prev == null || next == null) {
#         return;
#       }
#
#       var require = window.require.config({
#         context: "impression_neo_shopping_extension",
#         paths: {
#           "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#         }
#       });
#       require(["egjsConveyer"], function (egjsConveyer) {
#         var conveyer = new egjsConveyer("#shopping_flicking", {autoInit: false, preventClickOnDrag: true});
#
#
#         conveyer.subscribe("isReachStart", function (isReachStart) {
#           prev.style.display = isReachStart ? "none" : "block";
#         });
#
#         conveyer.subscribe("isReachEnd", function (isReachEnd) {
#           next.style.display = isReachEnd ? "none" : "block";
#         });
#         conveyer.init();
#
#         if (!conveyer.isReachEnd) {
#           next.style.display = "block";
#         }
#
#         prev.addEventListener("click", function () {
#           conveyer.scrollIntoView("start", {
#             align: "end",
#             duration: 500,
#             excludeStand: true,
#           });
#         });
#         next.addEventListener("click", function () {
#           conveyer.scrollIntoView("end", {
#             align: "start",
#             duration: 500,
#             excludeStand: true,
#           });
#         });
#       });
#     };
#     nhn.common.load_js(null, createShoppingImageConveyer, true, 150);
#   })();
# </script><section class="sc_new sp_related" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="mod_title_area"> <div class="title_wrap"> <h2 class="title">연관 검색어</h2> <span class="sub"><a class="api_ad_link" href="https://help.naver.com/alias/search/word/word_1.naver" onclick="return goOtherCR(this, 'a=rsk_top.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" role="button" target="_blank"><i class="spnew api_ico_help">도움말</i></a></span> </div> <div class="title_sub"> <a class="btn_report" href="https://help.naver.com/support/alias/search/word/word_2.naver" onclick="return goOtherCR(this, 'a=rsk_top.report&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><span class="txt">신고</span></a><a class="btn_close _close" href="#" onclick="return tCR('a=rsk_top.1fold&amp;r=1&amp;i=');"><i class="spnew api_ico_close4">검색어제안 기능 닫기</i></a> </div> </div> <div class="related_srch"> <ul class="lst_related_srch _list_box"> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%8F%88%EA%B0%80%EC%8A%A4+%EB%A7%9B%EC%A7%91&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=1&amp;u=' + urlencode(this.href))"> <div class="tit">돈가스 맛집</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%8F%88%EA%B0%80%EC%8A%A4%ED%81%B4%EB%9F%BD&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=2&amp;u=' + urlencode(this.href))"> <div class="tit">돈가스클럽</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%ED%99%8D%EC%9D%B5%EB%8F%88%EA%B0%80%EC%8A%A4&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=3&amp;u=' + urlencode(this.href))"> <div class="tit">홍익돈가스</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%82%98%EB%8A%94+%EB%8F%88%EA%B0%80%EC%8A%A4%EA%B0%80+%EC%8B%AB%EC%96%B4%EC%9A%94&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=4&amp;u=' + urlencode(this.href))"> <div class="tit">나는 돈가스가 싫어요</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%8F%88%EA%B0%80%EC%8A%A4+%EC%86%8C%EC%8A%A4+%EB%A7%8C%EB%93%A4%EA%B8%B0&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=5&amp;u=' + urlencode(this.href))"> <div class="tit">돈가스 소스 만들기</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%88%9C%EC%B2%9C%EC%8B%A0%EB%8C%80+%EB%8F%88%EA%B0%80%EC%8A%A4&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=6&amp;u=' + urlencode(this.href))"> <div class="tit">순천신대 돈가스</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%8F%88%EA%B0%80%EC%8A%A4+%EB%A7%8C%EB%93%A4%EA%B8%B0&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=7&amp;u=' + urlencode(this.href))"> <div class="tit">돈가스 만들기</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%82%A8%EC%82%B0%EB%8F%88%EA%B0%80%EC%8A%A4&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=8&amp;u=' + urlencode(this.href))"> <div class="tit">남산돈가스</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%B5%9C%EA%B3%A0%EB%8B%B9%EB%8F%88%EA%B0%80%EC%8A%A4&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=9&amp;u=' + urlencode(this.href))"> <div class="tit">최고당돈가스</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EB%8C%80%EA%B5%AC+%EC%A0%84%EC%9B%90%EB%8F%88%EA%B0%80%EC%8A%A4&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=10&amp;u=' + urlencode(this.href))"> <div class="tit">대구 전원돈가스</div> </a ...

# %%
items = soup.select('.title_link')
items
# Out:
# [<a class="title_link" data-cb-target="90000003_000000000000003415E6A656" data-cb-trigger="" href="https://blog.naver.com/h_sj0117/223705736790" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=1&amp;i=90000003_000000000000003415E6A656&amp;u='+urlencode(this.href));" target="_blank">광교 갤러리아 <mark>돈까스</mark> 맛집 정돈 정통 일식</a>,
#  <a class="title_link" data-cb-target="90000003_00000000000000341716F92A" data-cb-trigger="" href="https://blog.naver.com/hane1982/223725680938" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=2&amp;i=90000003_00000000000000341716F92A&amp;u='+urlencode(this.href));" target="_blank">혜화역 <mark>돈까스</mark> 정돈 대학로점</a>,
#  <a class="title_link" data-cb-target="90000003_000000000000003415FB5F4B" data-cb-trigger="" href="https://blog.naver.com/smin_ji/223707094859" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=3&amp;i=90000003_000000000000003415FB5F4B&amp;u='+urlencode(this.href));" target="_blank">줄 서서 먹는 여의도 점심 맛집 왕<mark>돈가스</mark>로 유명한 거창돈까스</a>,
#  <a class="title_link" data-cb-target="90000003_000000000000003417B2F399" data-cb-trigger="" href="https://blog.naver.com/wlsgk39/223735903129" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=4&amp;i=90000003_000000000000003417B2F399&amp;u='+urlencode(this.href));" target="_blank">[경산맛집]경산<mark>돈까스</mark>뷔페 유생촌</a>,
#  <a class="title_link" data-cb-target="90000003_000000000000003417BB4E26" data-cb-trigger="" href="https://blog.naver.com/armn1201/223736450598" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r