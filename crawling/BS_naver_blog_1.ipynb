# %% [markdown]
# # 네이버 블로그 검색결과 크롤링 (1)

# %%
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query='

# %%
keyword = input()

# %%
search_url = base_url + keyword
search_url
# Out:
# 'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query=우동'

# %%
r = requests.get(search_url)
r.text
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="우동 : 네이버 블로그검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'우동\'의 네이버 블로그검색 결과입니다."> <meta name="description" lang="ko" content="\'우동\'의 네이버 블로그검색 결과입니다."> <title>우동 : 네이버 블로그검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_250109.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_250116.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\\/\\*/, \'\').replace(/\\*\\//, \'\')); } function trim_crlf (q) { var crlf = /[\\r|\\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = \'utf-8\' ; document.getElementsByTagName(\'head\')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement(\'link\') ; l.type = \'text/css\' ; l.rel = \'stylesheet\' ; if (charset) l.charset = charset ; else l.charset = \'utf-8\' ; l.media = \'screen\' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=\'\'; mid.style.visibility=\'visible\'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden(\'"+id+"\')",100); } function hidden (id) { var mid=document.getElementById(id); ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="우동 : 네이버 블로그검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'우동'의 네이버 블로그검색 결과입니다." property="og:description"/> <meta content="'우동'의 네이버 블로그검색 결과입니다." lang="ko" name="description"/> <title>우동 : 네이버 블로그검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_250109.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_250116.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibility=' ...
# <form action="" id="view_form" method="get" name="view_form"> <input id="view_ssc" name="ssc" type="hidden" value="tab.blog.all"/> <input id="view_query" name="query" type="hidden" value="우동"/> <input id="view_sm" name="sm" type="hidden" value="tab_opt"/> <input id="view_nso" name="nso" type="hidden" value=""/> </form> <script> function view_init_form() { document.forms["view_form"]["query"].value = decodeURIComponent("%EC%9A%B0%EB%8F%99"); document.forms["view_form"]["nso"].value = decodeURIComponent(""); } function view_submit_sort_option(value) { view_init_form(); var area = ""; if (value == 1) { area = "new"; document.getElementById("view_form")["nso"].value = "so:dd,p:all"; } else { area = "sim"; document.getElementById("view_form")["nso"].value = "so:r,p:all"; } var cr = "opt." + area; formCR("view_form", cr); } function view_submit_date_option(value, e) { view_init_form(); var so = "r"; var cr = ""; if (value == 8) { var start = e.startDate; var end = e.endDate; var startdate = start.year + start.month + start.date; var enddate = end.year + end.month + end.date; var nso_startdate = startdate.replace(/\./gi, ""); var nso_enddate = enddate.replace(/\./gi, ""); cr = "opt.set"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:from" + nso_startdate + "to" + nso_enddate; } else if (value == 1) { cr = "opt.1hr"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1h"; } else if (value == 2) { cr = "opt.1day"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1d"; } else if (value == 3) { cr = "opt.1week"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1w"; } else if (value == 4) { cr = "opt.1mon"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1m"; } else if (value == 5) { cr = "opt.3mon"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:3m"; } else if (value == 6) { cr = "opt.6mon"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:6m"; } else if (value == 7) { cr = "opt.1yr"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:1y"; } else { cr = "opt.all"; document.getElementById("view_form")["nso"].value = "so:" + so + ",p:all"; } formCR("view_form", cr); } </script> <div id="snb"> <div class="mod_group_option_filter _search_option_simple_wrap" style=""> <div class="mod_list_option_filter"> <div aria-label="정렬 필터를 선택하세요" class="option_area type_sort" role="listbox"> <a aria-selected="true" class="item" href="#" onclick="view_submit_sort_option(0); return false;" role="option">관련도순</a> <a aria-selected="false" class="item" href="#" onclick="view_submit_sort_option(1); return false;" role="option">최신순</a> </div> <div class="option_filter"> <a aria-expanded="false" aria-haspopup="listbox" aria-label="검색옵션 열기" class="btn_option _search_option_open_btn" href="javascript:;" onclick="tCR('a=opt.unfd');" role="button">옵션<i class="spnew ico_filter_arr"></i></a> </div> </div> </div> <div class="mod_group_option_sort _search_option_detail_wrap" role="listbox" style="display:none;"> <div class="mod_list_option_filter"> <div class="option_filter"> <a aria-expanded="true" aria-haspopup="listbox" aria-label="검색옵션 닫기" class="btn_option _search_option_close_btn" href="javascript:;" onclick="tCR('a=opt.fold');" role="button">옵션<i class="spnew ico_filter_arr"></i></a> </div> </div> <ul class="lst_option"> <li class="bx lineup"> <div class="bx_inner"> <strong class="tit">정렬</strong> <div class="option" role="tablist"> <a aria-selected="true" class="txt" href="#" onclick="view_submit_sort_option(0); return false;" role="tab">관련도순</a> <a aria-selected="false" class="txt" href="#" onclick="view_submit_sort_option(1); return false;" role="tab">최신순</a> </div> </div> </li> <li class="bx term"> <div class="bx_inner"> <strong class="tit">기간</strong> <div class="option" role="tablist"> <a aria-selected="true" class="txt" href="#" onclick="view_submit_date_option(0); return false;" role="tab">전체</a>  ...
#   if (typeof NAVER === "undefined") {
#     NAVER = {};
#   }
#   if (typeof NAVER.SEARCH_AD === "undefined") {
#     NAVER.SEARCH_AD = {};
#   }
#   NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#           clearTimeout(timerAttribute);
#           parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#   };
#   NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#           var timer = setTimeout(function () {
#               var tooltipElement = $Element(parentElement.query("._tooltip"));
#               tooltipElement.css("display", "none");
#           }, 100);
#           parentElement.attr("data-timer", timer);
#       }
#   };
#
#   var _elAdIndLayerTab = null;
#   var _elAdIndLayerTimeTab;
#   var _elDscNcautionTab = null;
#
#   function adInfoShowTab(el) {
#     if (_elAdIndLayerTab && _elAdIndLayerTab.visible()) {
#       return false;
#     } else {
#       if (!_elDscNcautionTab) {
#         _elDscNcautionTab = $Element(el).parent();
#       }
#       _elAdIndLayerTab = _elDscNcautionTab.next().next();
#       _elAdIndLayerTab.show();
#       _elAdIndLayerTimeTab = (new Date()).getTime();
#       return true;
#     }
#   }
#
#   function adInfoHideTab() {
#     if (_elAdIndLayerTab) {
#       _elAdIndLayerTab.hide();
#     }
#   }
#
#   function adInfoHideClickEventHandlerTab(e) {
#     if (_elAdIndLayerTimeTab + 200 < (new Date()).getTime()) adInfoHideTab();
#   }
#
#   document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerTab, false);
# </script>
# <script>
#   (function () {
#     var defaultFavicon = "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png";
#     naver.common.imageLazyLoader.onError(
#             naver.common.LazySrc.Handler.create({
#               "power-link-favicon-error": function ($img) {
#                 $img.attr("src", defaultFavicon);
#               }
#             })
#     );
#   })();
# </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/241121/css/nx_tab_powerlink.css" rel="stylesheet" type="text/css"/>
# <div class="sc_new ad_section section">
# <div class="api_subject_bx">
# <div class="mod_title_area">
# <div class="title_wrap">
# <h2 class="title">파워링크</h2>
# <span class="sub">
# <span class="title_text">
# <em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">우동</strong>
# <em class="dsc_ncaution_quotation">’</em>관련광고
#             </span>
# </span>
# <a class="api_ad_link" href="javascript:void(0);" onclick="if(adInfoShowTab(this)) goOtherCR(this, 'a=tsa.adset&amp;r=0&amp;i=tsaadset&amp;u='+urlencode(this.href));" role="button">
# <i class="spnew api_ico_alert">이 광고가 표시된 이유</i>
# </a>
# </div>
# <div class="title_sub">
# <a class="sub_link" href="//saedu.naver.com/adbiz/searchad/clickChoice.naver" onclick="return goOtherCR(this, 'a=tsa.registration&amp;r=0&amp;i=tsaregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ly_api_info" style="display: none;">
# <p class="dsc">이 광고는 사이트검색광고(파워링크)로, 검색어와 광고의 연관도, 광고주의 입찰가 등에 의해 광고 노출 여부와 순위가 결정됩니다.</p>
# <div class="btn_area">
# <a class="link" href="https://help.naver.com/service/5626/contents/1419">도움말</a>
# </div>
# <button class="btn_close" onclick="adInfoHideTab();" type="button">
# <i class="spnew ico_close">정보확인 레이어 닫기</i>
# </button>
# </div>
# </div>
# <div class="nad_area">
# <ul class="lst_type">
# <li class="lst many_txt" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=+/ZeSS9ypnC88YiQMpa1dv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=1&amp;i=nad-a001-01-000000291620756&amp;d='+urlencode('https://xn--2q1bl4in2b95pbxbmzh.com/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fxn--2q1bl4in2b95pbxbmzh.com%2Fimages%2Ffavi.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=+/ZeSS9ypnC88YiQMpa1dv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000291620756&amp;d='+urlencode('https://xn--2q1bl4in2b95pbxbmzh.com/')+'&amp;u='+urlencode(this.href));" target="_blank">1980미아리우동집</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=+/ZeSS9ypnC88YiQMpa1dv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=1&amp;i=nad-a001-01-000000291620756&amp;d='+urlencode('https://xn--2q1bl4in2b95pbxbmzh.com/')+'&amp;u='+urlencode(this.href));" target="_blank">xn--2q1bl4in2b95pbxbmzh.com/</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=+/ZeSS9ypnC88YiQMpa1dv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=1&amp;i=nad-a001-01-000000291620756&amp;d=' + urlencode('https://xn--2q1bl4in2b95pbxbmzh.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">1980년 전통 가맹비면제</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=+/ZeSS9ypnC88YiQMpa1dv///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=1&amp;i=nad-a001-01-000000291620756&amp;d=' + urlencode('https://xn--2q1bl4in2b95pbxbmzh.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       MBC나혼자산다 김대호 극찬한 40년 오랜시간 노력으로 만든 24시 미아리<strong class="hl">우동</strong>집
#                     </p>
# </a>
# </div>
# </div>
# </li>
# <li class="lst many_txt ext_link type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=NWZkTnoAMKpRmbRcPPnWnv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fimg.cjthemarket.com%2Fcjom%2Fweb%2Fimages%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <div class="ico_area">
# <div class="ico">
# <div alt="네이버페이" class="sp_tabview npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">
# <span class="blind">n페이</span>
# </div>
# <a class="ly_ad _tooltip" href="https://m.pay.naver.com/mobile/about" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=tsa.checkout&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display: none;" target="_blank">
# <span class="ly_box">
# <span class="ly_txt">네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# <span class="sp_nad ly_tail"></span>
# </a>
# </div>
# </div>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=NWZkTnoAMKpRmbRcPPnWnv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">CJ더마켓</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=NWZkTnoAMKpRmbRcPPnWnv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">cjthemarket.com</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=NWZkTnoAMKpRmbRcPPnWnv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d=' + urlencode('http://www.cjthemarket.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">CJ제일제당 공식몰 더마켓</span><span class="lnk_tit_txt">최대 80% 더세페 특가</span><span class="lnk_tit_txt">월 990원 멤버십 무료배송</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=NWZkTnoAMKpRmbRcPPnWnv///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d=' + urlencode('http://www.cjthemarket.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       개별 포장으로 더 간편해진 면 요리! CJ더마켓에서 미식 여행 떠나보세요.
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=NWZkTnoAMKpRmbRcPPnWnv///w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d=' + urlencode('http://www.cjthemarket.com') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAyNDA3MDdfMTUg/MDAxNzIwMzI2MDg4MzU1.sIXe9aVR_wjmTLGMb9qy24b2IAFYWdNa2Jfj-BAOYkEg.7ijvVIvVRuvR9mZyupW0HMP4Z4E1n4c-0dlYrRf9bNwg.PNG/122375-47fea725-0922-48bd-9bff-5df50c75442e.png" width="68"/>
# </a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=EqVH2M1xCqCfX1sEkOZxiP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink1&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">쿠폰팩</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=j2w+QjCVmGrIKZyf3C+VnP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink2&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">이벤트</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=vb4LpA/0Hpz3Fs7Ww3PJgv///w==..." onclick="return goOtherCR(this,'a=tsa.sublink3&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">CJ 신제품</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=YwDKsR4j42vGf9kAtuFulP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink4&amp;r=2&amp;i=nad-a001-01-000000304320708&amp;d='+urlencode('http://www.cjthemarket.com')+'&amp;u='+urlencode(this.href));" target="_blank">핫딜</a>
# </li>
# </ul>
# </li>
# <li class="lst many_txt ext_shopping_single" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=kSd5F83mEA1kqe0471MFbP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;d='+urlencode('https://smartstore.naver.com/horangyimall')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimg-shop.pstatic.net%2Ffront%2Fnaver_favicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <div class="ico_area">
# <div class="ico">
# <div alt="네이버페이" class="sp_tabview npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">
# <span class="blind">n페이</span>
# </div>
# <a class="ly_ad _tooltip" href="https://m.pay.naver.com/mobile/about" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=tsa.checkout&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display: none;" target="_blank">
# <span class="ly_box">
# <span class="ly_txt">네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# <span class="sp_nad ly_tail"></span>
# </a>
# </div>
# </div>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=kSd5F83mEA1kqe0471MFbP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;d='+urlencode('https://smartstore.naver.com/horangyimall')+'&amp;u='+urlencode(this.href));" target="_blank">주식회사호랑이</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=kSd5F83mEA1kqe0471MFbP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;d='+urlencode('https://smartstore.naver.com/horangyimall')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/horangyimall</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=kSd5F83mEA1kqe0471MFbP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;d=' + urlencode('https://smartstore.naver.com/horangyimall') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">우불식당 즉석<strong class="hl">우동</strong> 봉지 라면</span><span class="lnk_tit_txt">수많은 리뷰어들의 극찬!</span>
# </a>
# </div>
# <a class="ext_shopping_item" href="https://adcr.naver.com/adcr?x=Pr2fquU7FRABDhL25wVT7f///w==..." onclick="return goOtherCR(this,'a=tsa.shpweb&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;d='+urlencode('https://smartstore.naver.com/horangyimall') + '&amp;u='+urlencode(this.href));" target="_blank">
# <div class="thumb_ext">
# <img src="https://shopping-phinf.pstatic.net/main_8717084/87170842623.5.jpg?type=f200"/>
# </div>
# <div class="info_ext">
# <span class="product">우불식당 즉석우동 봉지 라면 4EA</span>
# <span class="price"><strong>14,000</strong>원</span>
# <div class="unit">
# <span class="rating">4.8<span class="review">(3,115)</span></span>
# <span class="count">구매 2,702</span>
# <span class="count">찜 2,810</span>
# </div>
# </div>
# </a>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=kSd5F83mEA1kqe0471MFbP///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=3&amp;i=nad-a001-01-000000348204281&amp;d=' + urlencode('https://smartstore.naver.com/horangyimall') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       주식회사 호랑이 정품 식품을 만나볼 수 있는 단 하나의 공식몰
#                     </p>
# </a>
# </div>
# </div>
# </li>
# <li class="lst many_txt ext_link type_img" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=jHcEIhtLye/2RE4CWVLVqf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.jumpoline.com%2F_images%2Fcommon%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=jHcEIhtLye/2RE4CWVLVqf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">점포라인</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=jHcEIhtLye/2RE4CWVLVqf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">jumpoline.com</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=jHcEIhtLye/2RE4CWVLVqf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d=' + urlencode('http://www.jumpoline.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">돈까스<strong class="hl">우동</strong>점 매매 점포라인</span><span class="lnk_tit_txt">빠른 직거래 &amp; 안전중개거래</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=jHcEIhtLye/2RE4CWVLVqf///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d=' + urlencode('http://www.jumpoline.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                       31년전통, 100% 실매물, 매출보증, 주인 직접통화, 직거래, 150명에이전트
#                     </p>
# </a>
# </div>
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=jHcEIhtLye/2RE4CWVLVqf///w==..." onclick="return goOtherCR(this, 'a=tsa.image&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d=' + urlencode('http://www.jumpoline.com') + '&amp;u='+ urlencode(this.href));" target="blank">
# <img height="68" src="https://searchad-phinf.pstatic.net/MjAyMDEwMDhfMjA3/MDAxNjAyMTE3NzM1MjQx.q_EZW24jWG1jNzUJ1rFuA9O0TYA_ggGWZZ8ely6OSr0g.hc_fJAGPoCxoAYtuEs2NKkdB0g4KwWfKxHogrg4OagUg.PNG/324779-9ae0e148-f7bb-471a-ac4d-1bc1168b8f83.png" width="68"/>
# </a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=N3ifNbc3sds/Q0GsltZDev///w==..." onclick="return goOtherCR(this,'a=tsa.sublink1&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">매물정보</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Cb2hSqCNy8emzCEaHoUwx////w==..." onclick="return goOtherCR(this,'a=tsa.sublink2&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">계약후기</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=S31WUKpf+6PiX7EfRUBxLP///w==..." onclick="return goOtherCR(this,'a=tsa.sublink3&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">매매상담</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=XNZ5k2t3lM/jwR4/LaJa5P///w==..." onclick="return goOtherCR(this,'a=tsa.sublink4&amp;r=4&amp;i=nad-a001-01-000000341089038&amp;d='+urlencode('http://www.jumpoline.com')+'&amp;u='+urlencode(this.href));" target="_blank">에이전트</a>
# </li>
# </ul>
# </li>
# <li class="lst many_txt ext_place" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=d0KjZYUvpRlYf/c3GLWhYv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=5&amp;i=nad-a001-01-000000348841904&amp;d='+urlencode('https://map.naver.com/p/entry/place/1119767235')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmap.naver.com%2Fv5%2Fassets%2Ficon%2Fapple-icon-57x57.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="ad_mark"><span class="blind">광고</span></span>
# <a class="site" href="https://adcr.naver.com/adcr?x=d0KjZYUvpRlYf/c3GLWhYv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000348841904&amp;d='+urlencode('https://map.naver.com/p/entry/place/1119767235')+'&amp;u='+urlencode(this.href));" target="_blank">브라운돈까스등촌점</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=d0KjZYUvpRlYf/c3GLWhYv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=tsa.url&amp;r=5&amp;i=nad-a001-01-000000348841904&amp;d='+urlencode('https://map.naver.com/p/entry/place/1119767235')+'&amp;u='+urlencode(this.href));" target="_blank">map.naver.com/p</a>
# </span>
# </div>
# <div class="info_wrap">
# <div class="inner">
# <div class="lnk_tit_area">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=d0KjZYUvpRlYf/c3GLWhYv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=5&amp;i=nad-a001-01-000000348841904&amp;d=' + urlencode('https://map.naver.com/p/entry/place/1119767235') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit_txt">100% 제주산 생돼지고기</span><span class="lnk_tit_txt">경양식 돈까스 맛집</span>
# </a>
# </div>
# <a class="desc_area" href="https://adcr.naver.com/adcr?x=d0KjZYUvpRlYf/c3GLWhYv///w==..." onclick="return goOtherCR(this, 'a=tsa.tit&amp;r=5&amp;i=nad-a001-01-000000348841904&amp;d=' + urlencode('https://map.naver.com/p/entry/place/1119767235') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <p class="desc">
#
#                     냉동NO! 19가지 재료를 사용한 브라운만의 특제비법소스
#                   </p>
# </a>
# </div>
# </div>
# <div class="place_image">
# <div class="thumb_list flicking-camera" id="place_flicking">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20241011_294%2F1728608610759Q461E_JPEG%2F1%2529%25C8%25AB%25BC%25F6%25C4%25A1%25C1%25EE_%25B5%25B7%25B1%25EE%25BD%25BA%2528%25C1%25A3%25B0%25A1%25B6%25F4%2529.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20241011_20%2F1728608610722BS0pY_JPEG%2F7%2529%25C5%25EB%25BB%25F5%25BF%25EC%25B1%25EE%25BD%25BA.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fnaverbooking-phinf.pstatic.net%2F20241025_189%2F1729830541203Jd6vr_PNG%2F8%2529%25C1%25A4%25BD%25C4A.png&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fnaverbooking-phinf.pstatic.net%2F20241025_208%2F1729830541311byQo0_JPEG%2F6%2529_%25B4%25DC%25C3%25BC%25C4%25C6.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20241011_91%2F1728608610840nKtGE_JPEG%2F2%2529_%25C8%25AB%25BC%25F6%25C4%25A1%25C1%25EE%25B5%25B7%25B1%25EE%25BD%25BA_%25C6%25F7%25BD%25BA%25C5%25CD.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20241011_141%2F1728608441118cU36R_JPEG%2FKakaoTalk_20240827_114010525_01.jpg&amp;type=a380"/>
# <span class="img_thumb_more"></span>
# </a>
# </div>
# <button class="prev_button" id="_place_prev_button" style="display:none">
# <span class="blind">이전으로 이동</span>
# </button>
# <button class="next_button" id="_place_next_button" style="display:none">
# <span class="blind">다음으로 이동</span>
# </button>
# </div>
# <a class="place_info" href="https://adcr.naver.com/adcr?x=bZoyiJpA8sZBEHLNntq6af///w==..." onclick="return goOtherCR(this,'a=tsa.place&amp;r=5&amp;i=nad-a001-01-000000348841904&amp;d='+urlencode('https://map.naver.com/p/entry/place/1119767235')+'&amp;u='+urlencode(this.href));" target="_blank">
# <div class="keyword_area">
# <span class="item">돈까스</span><span class="item">우장산</span><span class="item">이대서울병원</span><span class="item">발산역</span>
# </div>
# <div class="option_area">
# <span class="option">방문자리뷰 <span class="account">107</span></span>
# <span class="option"><span class="account">1~2만원 (1인)</span></span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     (function() {
#         var createPlaceImageConveyer = function() {
#             var prev = document.getElementById("_place_prev_button");
#             var next = document.getElementById("_place_next_button");
#             if (prev == null || next == null) {
#                 return;
#             }
#             prev.style.display = "none";
#             var require = window.require.config({
#                 context: "impression_neo_place_extension",
#                 paths: {
#                     "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#                 }
#             });
#             require(["egjsConveyer"], function(egjsConveyer) {
#                 var conveyer = new egjsConveyer("#place_flicking", { autoInit: false, preventClickOnDrag: true});
#
#
#                 conveyer.subscribe("isReachStart", function(isReachStart) {
#                     prev.style.display = isReachStart ? "none" : "block";
#                 });
#
#                 conveyer.subscribe("isReachEnd", function(isReachEnd) {
#                     next.style.display = isReachEnd ? "none" : "block";
#                 });
#                 conveyer.init();
#
#                 if (!conveyer.isReachEnd) {
#                     next.style.display = "block";
#                 }
#
#                 prev.addEventListener("click", function() {
#                     conveyer.scrollIntoView("start", {
#                         align: "end",
#                         duration: 500,
#                         excludeStand: true,
#                     });
#                 });
#                 next.addEventListener("click", function() {
#                     conveyer.scrollIntoView("end", {
#                         align: "start",
#                         duration: 500,
#                         excludeStand: true,
#                     });
#                 });
#             });
#         };
#         nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#     })();
# </script>
# <script type="text/javascript">
#   (function () {
#     var createShoppingImageConveyer = function () {
#       var prev = document.getElementById("_shopping_prev_button");
#       var next = document.getElementById("_shopping_next_button");
#       if (prev == null || next == null) {
#         return;
#       }
#
#       var require = window.require.config({
#         context: "impression_neo_shopping_extension",
#         paths: {
#           "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#         }
#       });
#       require(["egjsConveyer"], function (egjsConveyer) {
#         var conveyer = new egjsConveyer("#shopping_flicking", {autoInit: false, preventClickOnDrag: true});
#
#
#         conveyer.subscribe("isReachStart", function (isReachStart) {
#           prev.style.display = isReachStart ? "none" : "block";
#         });
#
#         conveyer.subscribe("isReachEnd", function (isReachEnd) {
#           next.style.display = isReachEnd ? "none" : "block";
#         });
#         conveyer.init();
#
#         if (!conveyer.isReachEnd) {
#           next.style.display = "block";
#         }
#
#         prev.addEventListener("click", function () {
#           conveyer.scrollIntoView("start", {
#             align: "end",
#             duration: 500,
#             excludeStand: true,
#           });
#         });
#         next.addEventListener("click", function () {
#           conveyer.scrollIntoView("end", {
#             align: "start",
#             duration: 500,
#             excludeStand: true,
#           });
#         });
#       });
#     };
#     nhn.common.load_js(null, createShoppingImageConveyer, true, 150);
#   })();
# </script><section class="sc_new sp_related" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="mod_title_area"> <div class="title_wrap"> <h2 class="title">연관 검색어</h2> <span class="sub"><a class="api_ad_link" href="https://help.naver.com/alias/search/word/word_1.naver" onclick="return goOtherCR(this, 'a=rsk_top.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" role="button" target="_blank"><i class="spnew api_ico_help">도움말</i></a></span> </div> <div class="title_sub"> <a class="btn_report" href="https://help.naver.com/support/alias/search/word/word_2.naver" onclick="return goOtherCR(this, 'a=rsk_top.report&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><span class="txt">신고</span></a><a class="btn_close _close" href="#" onclick="return tCR('a=rsk_top.1fold&amp;r=1&amp;i=');"><i class="spnew api_ico_close4">검색어제안 기능 닫기</i></a> </div> </div> <div class="related_srch"> <ul class="lst_related_srch _list_box"> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%ED%95%9C%EC%8B%A0%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=1&amp;u=' + urlencode(this.href))"> <div class="tit">한신우동</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%97%AD%EC%A0%84%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=2&amp;u=' + urlencode(this.href))"> <div class="tit">역전우동</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EA%B9%A1%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=3&amp;u=' + urlencode(this.href))"> <div class="tit">깡우동</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EA%B8%B8%EB%8F%99%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=4&amp;u=' + urlencode(this.href))"> <div class="tit">길동우동</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%88%98%EC%9C%A0%EB%A6%AC%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=5&amp;u=' + urlencode(this.href))"> <div class="tit">수유리우동</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%83%9D%EC%83%9D%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=6&amp;u=' + urlencode(this.href))"> <div class="tit">생생우동</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%9A%B0%EB%8F%99+%EB%A7%9B%EC%A7%91&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=7&amp;u=' + urlencode(this.href))"> <div class="tit">우동 맛집</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%9A%B0%EB%8F%99+%EB%A7%8C%EB%93%A4%EA%B8%B0&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=8&amp;u=' + urlencode(this.href))"> <div class="tit">우동 만들기</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%9A%B0%EB%8F%99%EC%A7%91&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=9&amp;u=' + urlencode(this.href))"> <div class="tit">우동집</div> </a> </li> <li class="item"> <a class="keyword" href="?where=&amp;ssc=tab.blog.all&amp;query=%EC%A6%89%EC%84%9D%EC%9A%B0%EB%8F%99&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=10&amp;u=' + urlencode(this.href))"> <div class="tit">즉석우동</div> </a> </li> </ul> <div class="btn_area"> <a class="btn_more _more" href="#" onclick="return tCR('a=rsk_top.open');" role="button" style="display:none"><i class="spnew api_ico_open">더보기</i></a> </div> <div class="closed">1주일간 닫힘 상태가 유지됩니다. 다시 보시겠습 ...

# %%
items = soup.select('.title_link')
items
# Out:
# [<a class="title_link" data-cb-target="90000003_0000000000000034180CC5AE" data-cb-trigger="" href="https://blog.naver.com/haejunge/223741789614" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=1&amp;i=90000003_0000000000000034180CC5AE&amp;u='+urlencode(this.href));" target="_blank">인천 송도 맛집 데이트하기 좋은 마루젠<mark>우동</mark> 후기</a>,
#  <a class="title_link" data-cb-target="90000003_000000000000003415DCFD72" data-cb-trigger="" href="https://blog.naver.com/yunt80/223705103730" onclick="return goOtherCR(this,'a=blg*f.nblg&amp;r=2&amp;i=90000003_000000000000003415DCFD72&amp;u='+urlencode(this.href));" target="_blank">부산 장산역 점심 맛집 <mark>우동</mark>과 밥을 동시에 즐기는 동동국밥</a>,
#  <a class="title_link" data-cb-target="90000003_0000000000000034180DB8B0" data-cb-trigger="" href="https://blog.naver.com/winupsplay/223741851824" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=3&amp;i=90000003_0000000000000034180DB8B0&amp;u='+urlencode(this.href));" target="_blank">용인 유림동 맛집 솔솔<mark>우동</mark> 인생닭튀김 먹고온 후기</a>,
#  <a class="title_link" data-cb-target="90000003_00000000000000341831B4FA" data-cb-trigger="" href="https://blog.naver.com/aldusltkfkd/223744210170" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=4&amp;i=90000003_00000000000000341831B4FA&amp;u='+urlencode(this.href));" target="_blank">이수역 맛집 일식 코시 이수점 ; 치즈돈카츠 에비동 가마타마<mark>우동</mark></a>,
#  <a class="title_link" data-cb-target="00055f7ca0_0002ced0ed" data-cb-trigger="" href="https://post.naver.com/viewer/postView.naver?volumeNo=47108333&amp;memberNo=30298297&amp;vType=VERTICAL" onclick="return goOtherCR(this,'a=blg*s.nblg&amp;r=5&amp;i=00055f7ca0_0002ced0ed&amp;u='+urlencode(this.href));" target="_blank">[맛집추천] 추운 겨울 생각나는 <mark>우동</mark> 한 그릇, ‘냄비<mark>우동</mark>맛집 7선’</a>,
#  <a class="title_link" data-cb-target="90000003_0000000000000034173C6E68" data-cb-trigger="" href="https://blog.naver.com/papa_ma/223728135784" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=6&amp;i=90000003_0000000000000034173C6E68&amp;u='+urlencode(this.href));" target="_blank">서면 <mark>우동</mark> 맛집 요미우돈교자, 특별한 <mark>우동</mark>이 있는 웨이팅 맛집</a>,
#  <a class="title_link" data-cb-target="90000003_000000000000003417FDE473" data-cb-trigger="" href="https://blog.naver.com/jongha1025/223740814451" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=7&amp;i=90000003_000000000000003417FDE473&amp;u='+urlencode(this.href));" target="_blank">오산 원동 맛집 2차로 가기 좋은 가격도 착한 홍아저씨네 오뎅<mark>우동</mark></a>,
#  <a class="title_link" data-cb-target="90000003_000000000000003