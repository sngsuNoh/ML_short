# %%
from bs4 import BeautifulSoup
import requests

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
}

# %%
url = 'https://www.melon.com/chart/index.htm'

# %%
r = requests.get(url, headers=headers)

# %%
html = r.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
lst50 = soup.select('.lst50')
lst100 = soup.select('.lst100')
lst = lst50 + lst100

# %%
for e, i in enumerate(lst, 1):
    
    print(f'{e}위')
    
    title = i.select_one('.ellipsis.rank01 a')
    print(f'Title: {title.text}')
    
    artists = i.select('.ellipsis.rank02 > a')
    tmp = ''
    for artist in artists:
        tmp += artist.text
    print(f'Artist(s): {tmp}')
    
    album = i.select_one('.ellipsis.rank03 > a')
    print(f'Album: {album.text}')
    print()
# Out:
# 1위
# Title: HOME SWEET HOME (feat. 태양, 대성)
# Artist(s): G-DRAGON
# Album: HOME SWEET HOME (feat. 태양, 대성)
#
# 2위
# Title: REBEL HEART
# Artist(s): IVE (아이브)
# Album: IVE EMPATHY
#
# 3위
# Title: Whiplash
# Artist(s): aespa
# Album: Whiplash - The 5th Mini Album
#
# 4위
# Title: APT.
# Artist(s): 로제 (ROSÉ)Bruno Mars
# Album: APT.
#
# 5위
# Title: 나는 반딧불
# Artist(s): 황가람
# Album: 나는 반딧불
#
# 6위
# Title: toxic till the end
# Artist(s): 로제 (ROSÉ)
# Album: rosie
#
# 7위
# Title: Drowning
# Artist(s): WOODZ
# Album: OO-LI
#
# 8위
# Title: 오늘만 I LOVE YOU
# Artist(s): BOYNEXTDOOR
# Album: 오늘만 I LOVE YOU
#
# 9위
# Title: HAPPY
# Artist(s): DAY6 (데이식스)
# Album: Fourever
#
# 10위
# Title: POWER
# Artist(s): G-DRAGON
# Album: POWER
#
# 11위
# Title: DRIP
# Artist(s): BABYMONSTER
# Album: DRIP
#
# 12위
# Title: 너와의 모든 지금
# Artist(s): 재쓰비 (JAESSBEE)
# Album: 너와의 모든 지금
#
# 13위
# Title: 내게 사랑이 뭐냐고 물어본다면
# Artist(s): 로이킴
# Album: 내게 사랑이 뭐냐고 물어본다면
#
# 14위
# Title: Welcome to the Show
# Artist(s): DAY6 (데이식스)
# Album: Fourever
#
# 15위
# Title: 소나기
# Artist(s): 이클립스 (ECLIPSE)
# Album: 선재 업고 튀어 OST Part 1
#
# 16위
# Title: 내 이름 맑음
# Artist(s): QWER
# Album: 2nd Mini Album 'Algorithm's Blossom'
#
# 17위
# Title: UP (KARINA Solo)
# Artist(s): aespa
# Album: SYNK : PARALLEL LINE - Special Digital Single
#
# 18위
# Title: Supernova
# Artist(s): aespa
# Album: Armageddon - The 1st Album
#
# 19위
# Title: 한 페이지가 될 수 있게
# Artist(s): DAY6 (데이식스)
# Album: The Book of Us : Gravity
#
# 20위
# Title: 천상연
# Artist(s): 이창섭
# Album: 천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB))
#
# 21위
# Title: 슬픈 초대장
# Artist(s): 순순희(지환)
# Album: 슬픈 초대장
#
# 22위
# Title: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# Artist(s): AKMU (악뮤)
# Album: 항해
#
# 23위
# Title: Mantra
# Artist(s): 제니 (JENNIE)
# Album: Mantra
#
# 24위
# Title: 예뻤어
# Artist(s): DAY6 (데이식스)
# Album: Every DAY6 February
#
# 25위
# Title: 고민중독
# Artist(s): QWER
# Album: 1st Mini Album 'MANITO'
#
# 26위
# Title: Love wins all
# Artist(s): 아이유
# Album: The Winning
#
# 27위
# Title: How Sweet
# Artist(s): NewJeans
# Album: How Sweet
#
# 28위
# Title: Supersonic
# Artist(s): 프로미스나인
# Album: Supersonic
#
# 29위
# Title: 너의 모든 순간
# Artist(s): 성시경
# Album: 별에서 온 그대 OST Part.7
#
# 30위
# Title: 나는 아픈 건 딱 질색이니까
# Artist(s): (여자)아이들
# Album: 2
#
# 31위
# Title: 첫 만남은 계획대로 되지 않아
# Artist(s): TWS (투어스)
# Album: TWS 1st Mini Album ‘Sparkling Blue’
#
# 32위
# Title: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# Artist(s): 너드커넥션 (Nerd Connection)
# Album: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
#
# 33위
# Title: Small girl (feat. 도경수(D.O.))
# Artist(s): 이영지
# Album: 16 Fantasy
#
# 34위
# Title: 비의 랩소디
# Artist(s): 임재현
# Album: 비의 랩소디
#
# 35위
# Title: I AM
# Artist(s): IVE (아이브)
# Album: I've IVE
#
# 36위
# Title: 미안해 미워해 사랑해
# Artist(s): Crush
# Album: 눈물의 여왕 OST Part.4
#
# 37위
# Title: number one girl
# Artist(s): 로제 (ROSÉ)
# Album: number one girl
#
# 38위
# Title: Magnetic
# Artist(s): 아일릿(ILLIT)
# Album: SUPER REAL ME
#
# 39위
# Title: 에피소드
# Artist(s): 이무진
# Album: 에피소드
#
# 40위
# Title: 사랑은 늘 도망가
# Artist(s): 임영웅
# Album: 신사와 아가씨 OST Part.2
#
# 41위
# Title: 헤어지자 말해요
# Artist(s): 박재정
# Album: 1집 Alone
#
# 42위
# Title: 모든 날, 모든 순간 (Every day, Every Moment)
# Artist(s): 폴킴
# Album: '키스 먼저 할까요?' OST Part.3
#
# 43위
# Title: Ditto
# Artist(s): NewJeans
# Album: NewJeans 'OMG'
#
# 44위
# Title: WAY 4 LUV
# Artist(s): PLAVE
# Album: ASTERUM : 134-1
#
# 45위
# Title: Igloo
# Artist(s): KISS OF LIFE
# Album: Lose Yourself
#
# 46위
# Title: Armageddon
# Artist(s): aespa
# Album: Armageddon - The 1st Album
#
# 47위
# Title: 인사
# Artist(s): 범진
# Album: 인사
#
# 48위
# Title: 살기 위해서
# Artist(s): 순순희
# Album: 살기 위해서
#
# 49위
# Title: 무제(無題) (Untitled, 2014)
# Artist(s): G-DRAGON
# Album: 권지용
#
# 50위
# Title: 첫 눈
# Artist(s): EXO
# Album: 겨울 스페셜 앨범 '12월의 기적 (Miracles In December)'
#
# 51위
# Title: 다정히 내 이름을 부르면
# Artist(s): 경서예지전건호
# Album: 다정히 내 이름을 부르면 (경서예지 x 전건호)
#
# 52위
# Title: Hype Boy
# Artist(s): NewJeans
# Album: NewJeans 1st EP 'New Jeans'
#
# 53위
# Title: 해야 (HEYA)
# Artist(s): IVE (아이브)
# Album: IVE SWITCH
#
# 54위
# Title: 주저하는 연인들을 위해
# Artist(s): 잔나비
# Album: 전설
#
# 55위
# Title: Pump Up The Volume!
# Artist(s): PLAVE
# Album: Pump Up The Volume!
#
# 56위
# Title: 클락션 (Klaxon)
# Artist(s): (여자)아이들
# Album: I SWAY
#
# 57위
# Title: Sticky
# Artist(s): KISS OF LIFE
# Album: Sticky
#
# 58위
# Title: 눈이 오잖아(Feat.헤이즈)
# Artist(s): 이무진
# Album: 눈이 오잖아(Feat.헤이즈)
#
# 59위
# Title: 녹아내려요
# Artist(s): DAY6 (데이식스)
# Album: Band Aid
#
# 60위
# Title: 사랑인가 봐
# Artist(s): 멜로망스
# Album: 사랑인가 봐 (사내맞선 OST 스페셜 트랙)
#
# 61위
# Title: Supernatural
# Artist(s): NewJeans
# Album: Supernatural
#
# 62위
# Title: 청바지
# Artist(s): 부석순 (SEVENTEEN)
# Album: 부석순 2nd Single Album 'TELEPARTY'
#
# 63위
# Title: 청춘만화
# Artist(s): 이무진
# Album: 만화 (滿花)
#
# 64위
# Title: 청혼하지 않을 이유를 못 찾았어
# Artist(s): 이무진
# Album: 청혼하지 않을 이유를 못 찾았어
#
# 65위
# Title: To. X
# Artist(s): 태연 (TAEYEON)
# Album: To. X - The 5th Mini Album
#
# 66위
# Title: Hug (포옹)
# Artist(s): RIIZE
# Album: Hug (포옹)
#
# 67위
# Title: 취중고백
# Artist(s): 김민석
# Album: 취중고백
#
# 68위
# Title: SPOT! (feat. JENNIE)
# Artist(s): 지코 (ZICO)
# Album: SPOT!
#
# 69위
# Title: 사건의 지평선
# Artist(s): 윤하 (YOUNHA)
# Album: YOUNHA 6th Album Repackage 'END THEORY : Final Edition'
#
# 70위
# Title: Dash
# Artist(s): PLAVE
# Album: 'Caligo Pt.1'
#
# 71위
# Title: Love 119
# Artist(s): RIIZE
# Album: Love 119
#
# 72위
# Title: Bubble Gum
# Artist(s): NewJeans
# Album: How Sweet
#
# 73위
# Title: 사막에서 꽃을 피우듯
# Artist(s): 우디 (Woody)
# Album: 사막에서 꽃을 피우듯
#
# 74위
# Title: Drama
# Artist(s): aespa
# Album: Drama - The 4th Mini Album
#
# 75위
# Title: Seven (feat. Latto) - Clean Ver.
# Artist(s): 정국
# Album: Seven (feat. Latto) - Clean Ver.
#
# 76위
# Title: Die With A Smile
# Artist(s): Lady GagaBruno Mars
# Album: Die With A Smile
#
# 77위
# Title: Boom Boom Bass
# Artist(s): RIIZE
# Album: RIIZING - The 1st Mini Album
#
# 78위
# Title: Congratulations
# Artist(s): DAY6 (데이식스)
# Album: The Day
#
# 79위
# Title: 우리 영화
# Artist(s): PLAVE
# Album: ASTERUM : 134-1
#
# 80위
# Title: 우리들의 블루스
# Artist(s): 임영웅
# Album: IM HERO
#
# 81위
# Title: Cherish (My Love)
# Artist(s): 아일릿(ILLIT)
# Album: I’LL LIKE YOU
#
# 82위
# Title: 네모네모
# Artist(s): YENA (최예나)
# Album: 네모네모
#
# 83위
# Title: From
# Artist(s): PLAVE
# Album: ASTERUM : 134-1
#
# 84위
# Title: Dynamite
# Artist(s): 방탄소년단
# Album: Dynamite (DayTime Version)
#
# 85위
# Title: 온기
# Artist(s): 임영웅
# Album: 온기
#
# 86위
# Title: 봄날
# Artist(s): 방탄소년단
# Album: YOU NEVER WALK ALONE
#
# 87위
# Title: Love Hangover (feat. Dominic Fike)
# Artist(s): 제니 (JENNIE)Dominic Fike
# Album: Love Hangover
#
# 88위
# Title: 모래 알갱이
# Artist(s): 임영웅
# Album: 모래 알갱이
#
# 89위
# Title: RIZZ
# Artist(s): PLAVE
# Album: 'Caligo Pt.1'
#
# 90위
# Title: Chroma Drift
# Artist(s): PLAVE
# Album: 'Caligo Pt.1'
#
# 91위
# Title: 다시 만날 수 있을까
# Artist(s): 임영웅
# Album: IM HERO
#
# 92위
# Title: Watch Me Woo!
# Artist(s): PLAVE
# Album: ASTERUM : 134-1
#
# 93위
# Title: 이제 나만 믿어요
# Artist(s): 임영웅
# Album: 내일은 미스터트롯 우승자 특전곡
#
# 94위
# Title: Home
# Artist(s): 임영웅
# Album: 온기
#
# 95위
# Title: 12:32 (A to T)
# Artist(s): PLAVE
# Album: 'Caligo Pt.1'
#
# 96위
# Title: Island
# Artist(s): PLAVE
# Album: 'Caligo Pt.1'
#
# 97위
# Title: 봄여름가을겨울 (Still Life)
# Artist(s): BIGBANG (빅뱅)
# Album: 봄여름가을겨울 (Still Life)
#
# 98위
# Title: 우리의 다정한 계절 속에 (Season of Memories)
# Artist(s): 여자친구 (GFRIEND)
# Album: Season of Memories
#
# 99위
# Title: ATTITUDE
# Artist(s): IVE (아이브)
# Album: IVE EMPATHY
#
# 100위
# Title: 파이팅 해야지 (Feat. 이영지)
# Artist(s): 부석순 (SEVENTEEN)
# Album: 부석순 1st Single Album 'SECOND WIND'
